# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Metrics

# %%
a = np.array([1,2,3,4,5,6])
b = np.array([1,2,3,4,5,150])

# %%
np.mean(a), np.mean(b)
# Out:
# (3.5, 27.5)

# %%
np.median(a), np.median(b)
# Out:
# (3.5, 3.5)

# %%
np.std(a), np.std(b)
# Out:
# (1.707825127659933, 54.79887468430959)

# %% [markdown]
# ### Distributions

# %%
pd.Series(np.random.uniform(0,3,10000)).hist()
# Out:
# <Axes: >

# %%
pd.Series(np.random.normal(0,2,10000)).hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.displot(np.random.normal(0,2,10000), kde=True)

# %%
sns.displot(np.random.chisquare(5,10000), kde=True)

# %%
sns.displot(np.log(np.random.lognormal(size = 10000)), kde=True)

# %%
np.random.lognormal?

# %%
df = pd.read_csv('seattle-weather.csv')

# %%
log_prec = sns.displot(np.log(df['precipitation']))

# %%
sns.displot(df['wind'])

# %%
df[['precipitation','wind']].corr(method='kendall')
# Out:
#                precipitation      wind
# precipitation       1.000000  0.246457
# wind                0.246457  1.000000

# %%
df.corr?

# %%
wind = df['wind'].values

# %%
log_prec
