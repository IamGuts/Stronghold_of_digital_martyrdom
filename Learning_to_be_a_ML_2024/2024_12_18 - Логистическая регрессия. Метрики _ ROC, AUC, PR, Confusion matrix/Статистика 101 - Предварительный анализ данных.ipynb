# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = 500

# %%
from google.colab import files
files.upload()

# %%
df = pd.read_csv('CarPrice_Assignment.csv')

# %%
df.head()

# %% [markdown]
# ### Типы данных. Распределение. Преобразование данных

# %%
sns.distplot(df['enginesize'])

# %%
sns.scatterplot(data=df, x = 'enginesize', y = 'price')

# %%
sns.distplot(np.random.normal(loc=100,scale=10, size=50000))

# %% [markdown]
# ### Корреляция с условием
#
# Pearson, Spearman, Kendall
#
# Phik

# %%
col = ['curbweight','enginesize','horsepower','citympg','price']

# %%
df[col].corr(numeric_only=True)

# %%
sns.heatmap(df[col].corr(numeric_only=True), annot=True, fmt='0.2f')

# %%
st.pearsonr(df['compressionratio'], df['price'])

# %%
st.spearmanr(df['enginesize'], df['price'])

# %%
st.kendalltau(df['compressionratio'],df['price'])

# %%
df.corr(numeric_only=True)

# %%
# !pip install phik

# %%
import phik

# %%
phik.phik_matrix(df)

# %% [markdown]
# ### Оценка нормальности и вариативности данных
#
# Shapiro, normaltest
#
# Levene

# %%
st.shapiro(df['enginesize'])

# %%
st.normaltest(df['curbweight'])

# %%
st.levene(df['curbweight'],df['horsepower'])
